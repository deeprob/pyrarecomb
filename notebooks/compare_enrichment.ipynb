# %% [markdown]
# # Install pyrarecomb

# %%
# !pip install pyrarecomb==0.1.0
# Out:
# Collecting pyrarecomb==0.1.0
#   Downloading pyrarecomb-0.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: mlxtend in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.0) (0.22.0)
# Requirement already satisfied: pandas in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.0) (2.0.3)
# Requirement already satisfied: statsmodels in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.0) (0.14.0)
# Requirement already satisfied: scipy>=1.2.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (1.25.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (1.3.1)
# Requirement already satisfied: setuptools in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.0) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.0) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from statsmodels->pyrarecomb==0.1.0) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from statsmodels->pyrarecomb==0.1.0) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.0) (3.0.9)
# Requirement already satisfied: six in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels->pyrarecomb==0.1.0) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend->pyrarecomb==0.1.0) (3.1.0)
# Installing collected packages: pyrarecomb
#   Attempting uninstall: pyrarecomb
#     Found existing installation: pyrarecomb 0.0.3
#     Uninstalling pyrarecomb-0.0.3:
#       Successfully uninstalled pyrarecomb-0.0.3
# Successfully installed pyrarecomb-0.1.0

# %% [markdown]
# # Load test data

# %%
import pandas as pd

# %%
# load the input df
boolean_input_df = pd.read_csv("../example_data/test_input.csv")
# define all other params
combo_length = 2
min_indv_threshold = 5
max_freq_threshold = 0.25

# %% [markdown]
# # Run rarecomb

# %%
from pyrarecomb.compare_enrichment import compare_enrichment

# %%
out_df = compare_enrichment(
    boolean_input_df, combo_length, min_indv_threshold, max_freq_threshold,
    )
# Out:
# Number of cases remaining after filtration: 2488
# Number of controls remaining after filtration: 2512
# Number of items remaining after filtration: 334
# Number of initial combinations identified for cases: 293
# Number of unique items in cases: 95
# Number of controls: 2512
# Number of combinations with support of at least 2 in controls: 1357
# Number of combinations that are enriched in both cases and controls: 47
# Number of combinations considered for multiple testing correction: 246
# Number of combinations that are significant after multiple testing correction: 91
# Number of combinations with support less than 2 in controls: 37
# Number of significant combinations that meet the power threshold is 21
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Case_Adj_Pval_bonf'] = np.round(multipletests(sel_case_cont_freqitems_df['Case_pvalue_more'].values, method='bonferroni')[1], 3)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Case_Adj_Pval_BH'] = np.round(multipletests(sel_case_cont_freqitems_df['Case_pvalue_more'].values, method='fdr_bh')[1], 3)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Num_tests'] = number_of_tests
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df["Cont_Obs_Count_Combo"] = cont_combos_w_zero_freq_df.uniq_items.apply(get_counts, args=(apriori_input_controls_df, ))
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df["Cont_Obs_Prob_Combo"] = cont_combos_w_zero_freq_df['Cont_Obs_Count_Combo'] / number_of_controls
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df['Cont_pvalue_more'] = cont_combos_w_zero_freq_df.apply(lambda row: binomtest(int(row['Cont_Obs_Count_Combo']), number_of_controls, row['Cont_Exp_Prob_Combo'], alternative='greater').pvalue, axis=1)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Case_Exp_Count_Combo'] = round((all_sig_case_cont_freqitems_df['Case_Exp_Prob_Combo'] * number_of_cases), 2)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Cont_Exp_Count_Combo'] = round((all_sig_case_cont_freqitems_df['Cont_Exp_Prob_Combo'] * number_of_controls), 2)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Effect_Size'] = all_sig_case_cont_freqitems_df.apply(
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Power_One_Pct'] = round(all_sig_case_cont_freqitems_df.apply(
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Power_Five_Pct'] = round(all_sig_case_cont_freqitems_df.apply(

# %%
out_df
# Out:
#         Item_1     Item_2           uniq_items  Case_Obs_Count_Combo  \
# 5    Input_372  Input_328  Input_328|Input_372                   6.0
# 13   Input_372   Input_29   Input_29|Input_372                   5.0
# 54   Input_300   Input_39   Input_300|Input_39                   5.0
# 59   Input_153   Input_65   Input_153|Input_65                   8.0
# 73   Input_251  Input_342  Input_251|Input_342                   5.0
# 113  Input_250  Input_450  Input_250|Input_450                   5.0
# 127   Input_33  Input_462   Input_33|Input_462                   5.0
# 152  Input_348   Input_30   Input_30|Input_348                  10.0
# 154   Input_30  Input_342   Input_30|Input_342                   8.0
# 157   Input_30  Input_372   Input_30|Input_372                   5.0
# 178  Input_447  Input_250  Input_250|Input_447                   6.0
# 194  Input_234  Input_161  Input_161|Input_234                   6.0
# 199  Input_256  Input_224  Input_224|Input_256                   6.0
# 268  Input_269   Input_27   Input_269|Input_27                   7.0
# 270  Input_500   Input_60   Input_500|Input_60                   5.0
# 283   Input_24  Input_294   Input_24|Input_294                   5.0
# 284  Input_294  Input_342  Input_294|Input_342                   5.0
# 285  Input_234    Input_9    Input_234|Input_9                   6.0
# 288  Input_421  Input_349  Input_349|Input_421                   5.0
# 291  Input_119  Input_478  Input_119|Input_478                   5.0
# 292   Input_55  Input_353   Input_353|Input_55                   5.0
#
#      Case_Obs_Count_I1  Case_Obs_Count_I2  Case_Exp_Prob_Combo  \
# 5                   58                 72             0.000675
# 13                  58                 23             0.000216
# 54                  54                 35             0.000305
# 59                  27                 80             0.000349
# 73                  25                121             0.000489
# 113                142                 25             0.000573
# 127                 36                 73             0.000425
# 152                117                 49             0.000926
# 154                 49                121             0.000958
# 157                 49                 58             0.000459
# 178                 32                142             0.000734
# 194                165                 19             0.000506
# 199                 52                 77             0.000647
# 268                106                 34             0.000582
# 270                 84                 34             0.000461
# 283                 57                 19             0.000175
# 284                 19                121             0.000371
# 285                165                 17             0.000453
# 288                 55                 24             0.000213
# 291                 11                152             0.000270
# 292                 19                 14             0.000043
#
#      Case_Obs_Prob_Combo  Case_pvalue_more  Cont_Obs_Count_Combo  ...  \
# 5               0.002412      7.520220e-03                   0.0  ...
# 13              0.002010      2.361539e-04                   0.0  ...
# 54              0.002010      1.122807e-03                   0.0  ...
# 59              0.003215      3.681012e-06                   1.0  ...
# 73              0.002010      8.147192e-03                   0.0  ...
# 113             0.002010      1.530908e-02                   0.0  ...
# 127             0.002010      4.586176e-03                   0.0  ...
# 152             0.004019      1.445197e-04                   2.0  ...
# 154             0.003215      3.183206e-03                   0.0  ...
# 157             0.002010      6.327852e-03                   0.0  ...
# 178             0.002412      1.104879e-02                   0.0  ...
# 194             0.002412      1.905305e-03                   0.0  ...
# 199             0.002412      6.186712e-03                   0.0  ...
# 268             0.002814      7.539108e-04                   0.0  ...
# 270             0.002010      6.455869e-03                   0.0  ...
# 283             0.002010      9.048240e-05                   0.0  ...
# 284             0.002010      2.615619e-03                   0.0  ...
# 285             0.002412      1.092090e-03                   0.0  ...
# 288             0.002010      2.250565e-04                   0.0  ...
# 291             0.002010      6.535229e-04                   0.0  ...
# 292             0.002010      1.060869e-07                   0.0  ...
#
#      Case_Adj_Pval_bonf  Case_Adj_Pval_BH  Num_tests  Case_Exp_Count_Combo  \
# 5                 1.000             0.026        246                  1.68
# 13                0.058             0.003        246                  0.54
# 54                0.276             0.008        246                  0.76
# 59                0.001             0.000        246                  0.87
# 73                1.000             0.028        246                  1.22
# 113               1.000             0.043        246                  1.43
# 127               1.000             0.021        246                  1.06
# 152               0.036             0.003        246                  2.30
# 154               0.783             0.017        246                  2.38
# 157               1.000             0.024        246                  1.14
# 178               1.000             0.032        246                  1.83
# 194               0.469             0.012        246                  1.26
# 199               1.000             0.024        246                  1.61
# 268               0.185             0.006        246                  1.45
# 270               1.000             0.024        246                  1.15
# 283               0.022             0.002        246                  0.44
# 284               0.643             0.015        246                  0.92
# 285               0.269             0.008        246                  1.13
# 288               0.055             0.003        246                  0.53
# 291               0.161             0.006        246                  0.67
# 292               0.000             0.000        246                  0.11
#
#      Cont_Exp_Count_Combo  Effect_Size  Power_One_Pct  Power_Five_Pct  \
# 5                    1.43     0.098255          0.815           0.935
# 13                   0.42     0.089688          0.724           0.887
# 54                   0.52     0.089688          0.724           0.887
# 59                   0.90     0.073563          0.510           0.739
# 73                   0.86     0.089688          0.724           0.887
# 113                  0.63     0.089688          0.724           0.887
# 127                  1.05     0.089688          0.724           0.887
# 152                  1.89     0.070440          0.466           0.702
# 154                  1.42     0.113470          0.924           0.980
# 157                  0.80     0.089688          0.724           0.887
# 178                  1.16     0.098255          0.815           0.935
# 194                  1.57     0.098255          0.815           0.935
# 199                  1.47     0.098255          0.815           0.935
# 268                  2.25     0.106135          0.880           0.963
# 270                  0.83     0.089688          0.724           0.887
# 283                  0.25     0.089688          0.724           0.887
# 284                  0.49     0.089688          0.724           0.887
# 285                  1.50     0.098255          0.815           0.935
# 288                  0.38     0.089688          0.724           0.887
# 291                  0.37     0.089688          0.724           0.887
# 292                  0.07     0.089688          0.724           0.887
#
#                                           Case_Samples  \
# 5    Sample_1176|Sample_1867|Sample_2176|Sample_263...
# 13   Sample_7|Sample_370|Sample_399|Sample_2961|Sam...
# 54   Sample_568|Sample_1392|Sample_3244|Sample_3809...
# 59   Sample_9|Sample_170|Sample_906|Sample_1010|Sam...
# 73   Sample_982|Sample_2352|Sample_2447|Sample_2904...
# 113  Sample_865|Sample_1494|Sample_2566|Sample_4035...
# 127  Sample_2118|Sample_2838|Sample_3885|Sample_403...
# 152  Sample_247|Sample_868|Sample_1224|Sample_1525|...
# 154  Sample_389|Sample_1525|Sample_2734|Sample_3040...
# 157  Sample_1603|Sample_2118|Sample_2734|Sample_449...
# 178  Sample_87|Sample_302|Sample_1367|Sample_2998|S...
# 194  Sample_970|Sample_1175|Sample_1255|Sample_1306...
# 199  Sample_1725|Sample_1943|Sample_3096|Sample_393...
# 268  Sample_702|Sample_1921|Sample_1963|Sample_2269...
# 270  Sample_270|Sample_921|Sample_1965|Sample_2411|...
# 283  Sample_509|Sample_868|Sample_2186|Sample_2360|...
# 284  Sample_1465|Sample_2186|Sample_2360|Sample_238...
# 285  Sample_2449|Sample_2458|Sample_2862|Sample_382...
# 288  Sample_709|Sample_888|Sample_1805|Sample_1866|...
# 291  Sample_1010|Sample_1405|Sample_3799|Sample_473...
# 292  Sample_1425|Sample_2118|Sample_2284|Sample_403...
#
#              Control_Samples
# 5
# 13
# 54
# 59                Sample_368
# 73
# 113
# 127
# 152  Sample_1125|Sample_3073
# 154
# 157
# 178
# 194
# 199
# 268
# 270
# 283
# 284
# 285
# 288
# 291
# 292
#
# [21 rows x 25 columns]
