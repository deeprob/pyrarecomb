# %% [markdown]
# # Install pyrarecomb

# %%
# !pip install pyrarecomb==0.1.2
# Out:
# Requirement already satisfied: pyrarecomb==0.1.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (0.1.2)
# Requirement already satisfied: mlxtend in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.2) (0.22.0)
# Requirement already satisfied: pandas in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.2) (2.1.1)
# Requirement already satisfied: statsmodels in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pyrarecomb==0.1.2) (0.14.0)
# Requirement already satisfied: scipy>=1.2.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (1.25.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (1.3.1)
# Requirement already satisfied: setuptools in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from mlxtend->pyrarecomb==0.1.2) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.2) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from pandas->pyrarecomb==0.1.2) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from statsmodels->pyrarecomb==0.1.2) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from statsmodels->pyrarecomb==0.1.2) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend->pyrarecomb==0.1.2) (3.0.9)
# Requirement already satisfied: six in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels->pyrarecomb==0.1.2) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend->pyrarecomb==0.1.2) (3.1.0)

# %% [markdown]
# # Load test data

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
# load the input df
boolean_input_df = pd.read_csv("../example_data/test_input.csv")
# define all other params
combo_length = 2
min_indv_threshold = 5
max_freq_threshold = 0.25

# %% [markdown]
# # Run rarecomb

# %%
from pyrarecomb.compare_enrichment import compare_enrichment

# %%
out_df = compare_enrichment(
    boolean_input_df, combo_length, min_indv_threshold, max_freq_threshold,
    )
# Out:
# 334 itemset(s) from tree conditioned on items ()
# 7 itemset(s) from tree conditioned on items (Input_372)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_337)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_372, Input_65)
# 3 itemset(s) from tree conditioned on items (Input_499)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_342)
# 2 itemset(s) from tree conditioned on items (Input_223)
# 0 itemset(s) from tree conditioned on items (Input_223, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_223, Input_478)
# 1 itemset(s) from tree conditioned on items (Input_347)
# 0 itemset(s) from tree conditioned on items (Input_155)
# 2 itemset(s) from tree conditioned on items (Input_29)
# 0 itemset(s) from tree conditioned on items (Input_29, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_29, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_215)
# 1 itemset(s) from tree conditioned on items (Input_478)
# 7 itemset(s) from tree conditioned on items (Input_269)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_269, Input_342)
# 9 itemset(s) from tree conditioned on items (Input_65)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_65, Input_67)
# 7 itemset(s) from tree conditioned on items (Input_328)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_328, Input_224)
# 6 itemset(s) from tree conditioned on items (Input_336)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_401)
# 0 itemset(s) from tree conditioned on items (Input_336, Input_462)
# 3 itemset(s) from tree conditioned on items (Input_334)
# 0 itemset(s) from tree conditioned on items (Input_334, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_334, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_334, Input_365)
# 4 itemset(s) from tree conditioned on items (Input_325)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_342)
# 3 itemset(s) from tree conditioned on items (Input_39)
# 0 itemset(s) from tree conditioned on items (Input_39, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_39, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_39, Input_300)
# 4 itemset(s) from tree conditioned on items (Input_367)
# 0 itemset(s) from tree conditioned on items (Input_367, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_367, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_367, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_367, Input_348)
# 5 itemset(s) from tree conditioned on items (Input_153)
# 0 itemset(s) from tree conditioned on items (Input_153, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_153, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_153, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_153, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_153, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_414)
# 6 itemset(s) from tree conditioned on items (Input_337)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_337, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_376)
# 0 itemset(s) from tree conditioned on items (Input_78)
# 0 itemset(s) from tree conditioned on items (Input_485)
# 2 itemset(s) from tree conditioned on items (Input_250)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_331)
# 0 itemset(s) from tree conditioned on items (Input_288)
# 0 itemset(s) from tree conditioned on items (Input_392)
# 2 itemset(s) from tree conditioned on items (Input_251)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_274)
# 0 itemset(s) from tree conditioned on items (Input_137)
# 4 itemset(s) from tree conditioned on items (Input_272)
# 0 itemset(s) from tree conditioned on items (Input_272, Input_384)
# 0 itemset(s) from tree conditioned on items (Input_272, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_272, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_272, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_419)
# 2 itemset(s) from tree conditioned on items (Input_180)
# 0 itemset(s) from tree conditioned on items (Input_180, Input_137)
# 0 itemset(s) from tree conditioned on items (Input_180, Input_269)
# 1 itemset(s) from tree conditioned on items (Input_157)
# 0 itemset(s) from tree conditioned on items (Input_163)
# 0 itemset(s) from tree conditioned on items (Input_234)
# 3 itemset(s) from tree conditioned on items (Input_67)
# 0 itemset(s) from tree conditioned on items (Input_67, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_67, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_67, Input_250)
# 2 itemset(s) from tree conditioned on items (Input_276)
# 0 itemset(s) from tree conditioned on items (Input_276, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_276, Input_269)
# 1 itemset(s) from tree conditioned on items (Input_46)
# 0 itemset(s) from tree conditioned on items (Input_323)
# 1 itemset(s) from tree conditioned on items (Input_492)
# 0 itemset(s) from tree conditioned on items (Input_107)
# 0 itemset(s) from tree conditioned on items (Input_165)
# 0 itemset(s) from tree conditioned on items (Input_209)
# 0 itemset(s) from tree conditioned on items (Input_80)
# 0 itemset(s) from tree conditioned on items (Input_422)
# 0 itemset(s) from tree conditioned on items (Input_2)
# 3 itemset(s) from tree conditioned on items (Input_365)
# 0 itemset(s) from tree conditioned on items (Input_365, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_365, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_365, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_20)
# 0 itemset(s) from tree conditioned on items (Input_197)
# 0 itemset(s) from tree conditioned on items (Input_89)
# 1 itemset(s) from tree conditioned on items (Input_370)
# 0 itemset(s) from tree conditioned on items (Input_479)
# 2 itemset(s) from tree conditioned on items (Input_206)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_96)
# 5 itemset(s) from tree conditioned on items (Input_273)
# 0 itemset(s) from tree conditioned on items (Input_273, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_273, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_273, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_273, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_273, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_420)
# 0 itemset(s) from tree conditioned on items (Input_77)
# 0 itemset(s) from tree conditioned on items (Input_12)
# 0 itemset(s) from tree conditioned on items (Input_249)
# 8 itemset(s) from tree conditioned on items (Input_421)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_421, Input_342)
# 1 itemset(s) from tree conditioned on items (Input_45)
# 0 itemset(s) from tree conditioned on items (Input_237)
# 1 itemset(s) from tree conditioned on items (Input_426)
# 4 itemset(s) from tree conditioned on items (Input_500)
# 0 itemset(s) from tree conditioned on items (Input_500, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_500, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_500, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_500, Input_478)
# 1 itemset(s) from tree conditioned on items (Input_450)
# 0 itemset(s) from tree conditioned on items (Input_18)
# 4 itemset(s) from tree conditioned on items (Input_71)
# 0 itemset(s) from tree conditioned on items (Input_71, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_71, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_71, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_71, Input_342)
# 6 itemset(s) from tree conditioned on items (Input_327)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_327, Input_478)
# 1 itemset(s) from tree conditioned on items (Input_266)
# 3 itemset(s) from tree conditioned on items (Input_33)
# 0 itemset(s) from tree conditioned on items (Input_33, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_33, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_33, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_8)
# 0 itemset(s) from tree conditioned on items (Input_397)
# 0 itemset(s) from tree conditioned on items (Input_138)
# 0 itemset(s) from tree conditioned on items (Input_434)
# 0 itemset(s) from tree conditioned on items (Input_76)
# 0 itemset(s) from tree conditioned on items (Input_166)
# 1 itemset(s) from tree conditioned on items (Input_474)
# 0 itemset(s) from tree conditioned on items (Input_146)
# 5 itemset(s) from tree conditioned on items (Input_342)
# 0 itemset(s) from tree conditioned on items (Input_342, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_342, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_342, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_342, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_342, Input_234)
# 4 itemset(s) from tree conditioned on items (Input_84)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_67)
# 5 itemset(s) from tree conditioned on items (Input_438)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_327)
# 1 itemset(s) from tree conditioned on items (Input_50)
# 0 itemset(s) from tree conditioned on items (Input_171)
# 0 itemset(s) from tree conditioned on items (Input_227)
# 0 itemset(s) from tree conditioned on items (Input_408)
# 5 itemset(s) from tree conditioned on items (Input_224)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_327)
# 9 itemset(s) from tree conditioned on items (Input_30)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_372)
# 1 itemset(s) from tree conditioned on items (Input_91)
# 0 itemset(s) from tree conditioned on items (Input_457)
# 0 itemset(s) from tree conditioned on items (Input_6)
# 0 itemset(s) from tree conditioned on items (Input_11)
# 0 itemset(s) from tree conditioned on items (Input_277)
# 0 itemset(s) from tree conditioned on items (Input_59)
# 8 itemset(s) from tree conditioned on items (Input_462)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_462, Input_224)
# 10 itemset(s) from tree conditioned on items (Input_136)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_136, Input_224)
# 6 itemset(s) from tree conditioned on items (Input_447)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_447, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_109)
# 6 itemset(s) from tree conditioned on items (Input_118)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_118, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_388)
# 0 itemset(s) from tree conditioned on items (Input_169)
# 0 itemset(s) from tree conditioned on items (Input_236)
# 0 itemset(s) from tree conditioned on items (Input_13)
# 0 itemset(s) from tree conditioned on items (Input_431)
# 1 itemset(s) from tree conditioned on items (Input_428)
# 0 itemset(s) from tree conditioned on items (Input_381)
# 0 itemset(s) from tree conditioned on items (Input_145)
# 0 itemset(s) from tree conditioned on items (Input_127)
# 2 itemset(s) from tree conditioned on items (Input_7)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_360)
# 2 itemset(s) from tree conditioned on items (Input_284)
# 0 itemset(s) from tree conditioned on items (Input_284, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_284, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_494)
# 0 itemset(s) from tree conditioned on items (Input_188)
# 1 itemset(s) from tree conditioned on items (Input_161)
# 0 itemset(s) from tree conditioned on items (Input_281)
# 5 itemset(s) from tree conditioned on items (Input_256)
# 0 itemset(s) from tree conditioned on items (Input_256, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_256, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_256, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_256, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_256, Input_224)
# 3 itemset(s) from tree conditioned on items (Input_198)
# 0 itemset(s) from tree conditioned on items (Input_198, Input_337)
# 0 itemset(s) from tree conditioned on items (Input_198, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_198, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_212)
# 1 itemset(s) from tree conditioned on items (Input_203)
# 0 itemset(s) from tree conditioned on items (Input_487)
# 0 itemset(s) from tree conditioned on items (Input_358)
# 1 itemset(s) from tree conditioned on items (Input_115)
# 4 itemset(s) from tree conditioned on items (Input_425)
# 0 itemset(s) from tree conditioned on items (Input_425, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_425, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_425, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_425, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_99)
# 0 itemset(s) from tree conditioned on items (Input_267)
# 0 itemset(s) from tree conditioned on items (Input_452)
# 0 itemset(s) from tree conditioned on items (Input_231)
# 0 itemset(s) from tree conditioned on items (Input_286)
# 1 itemset(s) from tree conditioned on items (Input_384)
# 0 itemset(s) from tree conditioned on items (Input_278)
# 0 itemset(s) from tree conditioned on items (Input_69)
# 0 itemset(s) from tree conditioned on items (Input_37)
# 1 itemset(s) from tree conditioned on items (Input_257)
# 0 itemset(s) from tree conditioned on items (Input_411)
# 0 itemset(s) from tree conditioned on items (Input_41)
# 6 itemset(s) from tree conditioned on items (Input_335)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_370)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_269)
# 5 itemset(s) from tree conditioned on items (Input_348)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_455)
# 3 itemset(s) from tree conditioned on items (Input_295)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_118)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_480)
# 0 itemset(s) from tree conditioned on items (Input_476)
# 0 itemset(s) from tree conditioned on items (Input_371)
# 0 itemset(s) from tree conditioned on items (Input_162)
# 1 itemset(s) from tree conditioned on items (Input_22)
# 0 itemset(s) from tree conditioned on items (Input_254)
# 0 itemset(s) from tree conditioned on items (Input_87)
# 0 itemset(s) from tree conditioned on items (Input_241)
# 0 itemset(s) from tree conditioned on items (Input_40)
# 0 itemset(s) from tree conditioned on items (Input_150)
# 0 itemset(s) from tree conditioned on items (Input_122)
# 0 itemset(s) from tree conditioned on items (Input_73)
# 0 itemset(s) from tree conditioned on items (Input_123)
# 0 itemset(s) from tree conditioned on items (Input_178)
# 0 itemset(s) from tree conditioned on items (Input_114)
# 13 itemset(s) from tree conditioned on items (Input_486)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_256)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_486, Input_224)
# 1 itemset(s) from tree conditioned on items (Input_35)
# 3 itemset(s) from tree conditioned on items (Input_482)
# 0 itemset(s) from tree conditioned on items (Input_482, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_482, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_482, Input_342)
# 2 itemset(s) from tree conditioned on items (Input_132)
# 0 itemset(s) from tree conditioned on items (Input_132, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_132, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_134)
# 0 itemset(s) from tree conditioned on items (Input_28)
# 2 itemset(s) from tree conditioned on items (Input_300)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_374)
# 3 itemset(s) from tree conditioned on items (Input_310)
# 0 itemset(s) from tree conditioned on items (Input_310, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_310, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_310, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_104)
# 0 itemset(s) from tree conditioned on items (Input_179)
# 0 itemset(s) from tree conditioned on items (Input_446)
# 0 itemset(s) from tree conditioned on items (Input_307)
# 0 itemset(s) from tree conditioned on items (Input_275)
# 1 itemset(s) from tree conditioned on items (Input_401)
# 0 itemset(s) from tree conditioned on items (Input_301)
# 0 itemset(s) from tree conditioned on items (Input_344)
# 0 itemset(s) from tree conditioned on items (Input_195)
# 0 itemset(s) from tree conditioned on items (Input_72)
# 0 itemset(s) from tree conditioned on items (Input_49)
# 0 itemset(s) from tree conditioned on items (Input_207)
# 0 itemset(s) from tree conditioned on items (Input_287)
# 0 itemset(s) from tree conditioned on items (Input_31)
# 0 itemset(s) from tree conditioned on items (Input_283)
# 8 itemset(s) from tree conditioned on items (Input_24)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_328)
# 1 itemset(s) from tree conditioned on items (Input_240)
# 0 itemset(s) from tree conditioned on items (Input_314)
# 0 itemset(s) from tree conditioned on items (Input_418)
# 0 itemset(s) from tree conditioned on items (Input_168)
# 0 itemset(s) from tree conditioned on items (Input_90)
# 1 itemset(s) from tree conditioned on items (Input_497)
# 0 itemset(s) from tree conditioned on items (Input_329)
# 0 itemset(s) from tree conditioned on items (Input_253)
# 0 itemset(s) from tree conditioned on items (Input_308)
# 0 itemset(s) from tree conditioned on items (Input_464)
# 0 itemset(s) from tree conditioned on items (Input_239)
# 0 itemset(s) from tree conditioned on items (Input_173)
# 4 itemset(s) from tree conditioned on items (Input_445)
# 0 itemset(s) from tree conditioned on items (Input_445, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_445, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_445, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_445, Input_224)
# 1 itemset(s) from tree conditioned on items (Input_435)
# 0 itemset(s) from tree conditioned on items (Input_467)
# 1 itemset(s) from tree conditioned on items (Input_454)
# 0 itemset(s) from tree conditioned on items (Input_268)
# 0 itemset(s) from tree conditioned on items (Input_182)
# 0 itemset(s) from tree conditioned on items (Input_299)
# 1 itemset(s) from tree conditioned on items (Input_147)
# 2 itemset(s) from tree conditioned on items (Input_27)
# 0 itemset(s) from tree conditioned on items (Input_27, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_27, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_4)
# 0 itemset(s) from tree conditioned on items (Input_356)
# 0 itemset(s) from tree conditioned on items (Input_83)
# 2 itemset(s) from tree conditioned on items (Input_60)
# 0 itemset(s) from tree conditioned on items (Input_60, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_60, Input_234)
# 1 itemset(s) from tree conditioned on items (Input_222)
# 0 itemset(s) from tree conditioned on items (Input_379)
# 0 itemset(s) from tree conditioned on items (Input_289)
# 2 itemset(s) from tree conditioned on items (Input_47)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_472)
# 0 itemset(s) from tree conditioned on items (Input_292)
# 0 itemset(s) from tree conditioned on items (Input_319)
# 0 itemset(s) from tree conditioned on items (Input_42)
# 1 itemset(s) from tree conditioned on items (Input_158)
# 0 itemset(s) from tree conditioned on items (Input_404)
# 0 itemset(s) from tree conditioned on items (Input_193)
# 0 itemset(s) from tree conditioned on items (Input_290)
# 2 itemset(s) from tree conditioned on items (Input_55)
# 0 itemset(s) from tree conditioned on items (Input_55, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_55, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_52)
# 0 itemset(s) from tree conditioned on items (Input_357)
# 0 itemset(s) from tree conditioned on items (Input_225)
# 0 itemset(s) from tree conditioned on items (Input_375)
# 0 itemset(s) from tree conditioned on items (Input_436)
# 0 itemset(s) from tree conditioned on items (Input_415)
# 0 itemset(s) from tree conditioned on items (Input_68)
# 0 itemset(s) from tree conditioned on items (Input_187)
# 0 itemset(s) from tree conditioned on items (Input_21)
# 0 itemset(s) from tree conditioned on items (Input_483)
# 0 itemset(s) from tree conditioned on items (Input_429)
# 0 itemset(s) from tree conditioned on items (Input_407)
# 0 itemset(s) from tree conditioned on items (Input_98)
# 0 itemset(s) from tree conditioned on items (Input_43)
# 0 itemset(s) from tree conditioned on items (Input_385)
# 0 itemset(s) from tree conditioned on items (Input_149)
# 0 itemset(s) from tree conditioned on items (Input_468)
# 0 itemset(s) from tree conditioned on items (Input_170)
# 0 itemset(s) from tree conditioned on items (Input_75)
# 0 itemset(s) from tree conditioned on items (Input_113)
# 0 itemset(s) from tree conditioned on items (Input_317)
# 0 itemset(s) from tree conditioned on items (Input_175)
# 0 itemset(s) from tree conditioned on items (Input_444)
# 0 itemset(s) from tree conditioned on items (Input_466)
# 0 itemset(s) from tree conditioned on items (Input_451)
# 0 itemset(s) from tree conditioned on items (Input_293)
# 0 itemset(s) from tree conditioned on items (Input_403)
# 0 itemset(s) from tree conditioned on items (Input_270)
# 1 itemset(s) from tree conditioned on items (Input_296)
# 1 itemset(s) from tree conditioned on items (Input_199)
# 2 itemset(s) from tree conditioned on items (Input_205)
# 0 itemset(s) from tree conditioned on items (Input_205, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_205, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_230)
# 0 itemset(s) from tree conditioned on items (Input_469)
# 0 itemset(s) from tree conditioned on items (Input_459)
# 0 itemset(s) from tree conditioned on items (Input_391)
# 0 itemset(s) from tree conditioned on items (Input_380)
# 0 itemset(s) from tree conditioned on items (Input_108)
# 0 itemset(s) from tree conditioned on items (Input_390)
# 0 itemset(s) from tree conditioned on items (Input_303)
# 0 itemset(s) from tree conditioned on items (Input_442)
# 0 itemset(s) from tree conditioned on items (Input_88)
# 0 itemset(s) from tree conditioned on items (Input_484)
# 0 itemset(s) from tree conditioned on items (Input_244)
# 3 itemset(s) from tree conditioned on items (Input_294)
# 0 itemset(s) from tree conditioned on items (Input_294, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_294, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_294, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_406)
# 0 itemset(s) from tree conditioned on items (Input_394)
# 0 itemset(s) from tree conditioned on items (Input_217)
# 1 itemset(s) from tree conditioned on items (Input_9)
# 0 itemset(s) from tree conditioned on items (Input_430)
# 0 itemset(s) from tree conditioned on items (Input_410)
# 0 itemset(s) from tree conditioned on items (Input_441)
# 0 itemset(s) from tree conditioned on items (Input_213)
# 0 itemset(s) from tree conditioned on items (Input_413)
# 5 itemset(s) from tree conditioned on items (Input_349)
# 0 itemset(s) from tree conditioned on items (Input_349, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_349, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_349, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_349, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_349, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_200)
# 0 itemset(s) from tree conditioned on items (Input_57)
# 0 itemset(s) from tree conditioned on items (Input_260)
# 0 itemset(s) from tree conditioned on items (Input_490)
# 0 itemset(s) from tree conditioned on items (Input_133)
# 0 itemset(s) from tree conditioned on items (Input_10)
# 0 itemset(s) from tree conditioned on items (Input_95)
# 0 itemset(s) from tree conditioned on items (Input_396)
# 1 itemset(s) from tree conditioned on items (Input_119)
# 0 itemset(s) from tree conditioned on items (Input_496)
# 0 itemset(s) from tree conditioned on items (Input_440)
# 0 itemset(s) from tree conditioned on items (Input_97)
# 0 itemset(s) from tree conditioned on items (Input_3)
# 0 itemset(s) from tree conditioned on items (Input_463)
# 0 itemset(s) from tree conditioned on items (Input_383)
# 0 itemset(s) from tree conditioned on items (Input_475)
# 0 itemset(s) from tree conditioned on items (Input_194)
# 0 itemset(s) from tree conditioned on items (Input_255)
# 0 itemset(s) from tree conditioned on items (Input_74)
# 0 itemset(s) from tree conditioned on items (Input_66)
# 0 itemset(s) from tree conditioned on items (Input_102)
# 0 itemset(s) from tree conditioned on items (Input_54)
# 0 itemset(s) from tree conditioned on items (Input_298)
# 0 itemset(s) from tree conditioned on items (Input_176)
# 0 itemset(s) from tree conditioned on items (Input_112)
# 0 itemset(s) from tree conditioned on items (Input_427)
# 0 itemset(s) from tree conditioned on items (Input_183)
# 0 itemset(s) from tree conditioned on items (Input_202)
# 0 itemset(s) from tree conditioned on items (Input_416)
# 0 itemset(s) from tree conditioned on items (Input_189)
# 0 itemset(s) from tree conditioned on items (Input_398)
# 0 itemset(s) from tree conditioned on items (Input_350)
# 0 itemset(s) from tree conditioned on items (Input_177)
# 0 itemset(s) from tree conditioned on items (Input_382)
# 0 itemset(s) from tree conditioned on items (Input_172)
# 0 itemset(s) from tree conditioned on items (Input_460)
# 0 itemset(s) from tree conditioned on items (Input_285)
# 0 itemset(s) from tree conditioned on items (Input_417)
# 0 itemset(s) from tree conditioned on items (Input_412)
# 0 itemset(s) from tree conditioned on items (Input_362)
# 0 itemset(s) from tree conditioned on items (Input_235)
# 0 itemset(s) from tree conditioned on items (Input_453)
# 0 itemset(s) from tree conditioned on items (Input_232)
# 0 itemset(s) from tree conditioned on items (Input_471)
# 0 itemset(s) from tree conditioned on items (Input_312)
# 0 itemset(s) from tree conditioned on items (Input_116)
# 0 itemset(s) from tree conditioned on items (Input_106)
# 0 itemset(s) from tree conditioned on items (Input_364)
# 0 itemset(s) from tree conditioned on items (Input_51)
# 0 itemset(s) from tree conditioned on items (Input_247)
# 0 itemset(s) from tree conditioned on items (Input_246)
# 1 itemset(s) from tree conditioned on items (Input_353)
# 0 itemset(s) from tree conditioned on items (Input_70)
# 0 itemset(s) from tree conditioned on items (Input_437)
# 0 itemset(s) from tree conditioned on items (Input_488)
# 0 itemset(s) from tree conditioned on items (Input_461)
# 0 itemset(s) from tree conditioned on items (Input_399)
# 0 itemset(s) from tree conditioned on items (Input_229)
# 0 itemset(s) from tree conditioned on items (Input_82)
# 0 itemset(s) from tree conditioned on items (Input_103)
# 0 itemset(s) from tree conditioned on items (Input_333)
# 0 itemset(s) from tree conditioned on items (Input_191)
# 0 itemset(s) from tree conditioned on items (Input_443)
# 0 itemset(s) from tree conditioned on items (Input_361)
# 95 itemset(s) from tree conditioned on items ()
# 6 itemset(s) from tree conditioned on items (Input_348)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_348, Input_250)
# 8 itemset(s) from tree conditioned on items (Input_84)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_84, Input_234)
# 10 itemset(s) from tree conditioned on items (Input_335)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_335, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_234)
# 21 itemset(s) from tree conditioned on items (Input_22)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_337)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_300)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_7)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_206)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_499)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_30)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_27)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_22, Input_222)
# 12 itemset(s) from tree conditioned on items (Input_224)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_224, Input_84)
# 14 itemset(s) from tree conditioned on items (Input_115)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_137)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_118)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_115, Input_328)
# 4 itemset(s) from tree conditioned on items (Input_250)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_250, Input_67)
# 13 itemset(s) from tree conditioned on items (Input_300)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_180)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_276)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_205)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_300, Input_137)
# 22 itemset(s) from tree conditioned on items (Input_24)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_300)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_272)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_334)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_273)
# 0 itemset(s) from tree conditioned on items (Input_24, Input_365)
# 16 itemset(s) from tree conditioned on items (Input_206)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_300)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_273)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_272)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_454)
# 0 itemset(s) from tree conditioned on items (Input_206, Input_269)
# 27 itemset(s) from tree conditioned on items (Input_30)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_300)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_206)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_205)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_426)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_337)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_256)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_222)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_266)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_27)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_499)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_118)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_334)
# 0 itemset(s) from tree conditioned on items (Input_30, Input_137)
# 27 itemset(s) from tree conditioned on items (Input_7)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_30)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_206)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_334)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_222)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_266)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_157)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_256)
# 0 itemset(s) from tree conditioned on items (Input_7, Input_269)
# ...
# 0 itemset(s) from tree conditioned on items (Input_438, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_272)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_384)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_426)
# 0 itemset(s) from tree conditioned on items (Input_438, Input_310)
# 31 itemset(s) from tree conditioned on items (Input_499)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_256)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_336)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_205)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_273)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_372)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_334)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_91)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_296)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_421)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_370)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_198)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_137)
# 0 itemset(s) from tree conditioned on items (Input_499, Input_272)
# 10 itemset(s) from tree conditioned on items (Input_47)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_401)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_384)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_367)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_447)
# 0 itemset(s) from tree conditioned on items (Input_47, Input_136)
# 20 itemset(s) from tree conditioned on items (Input_295)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_136)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_273)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_300)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_445)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_500)
# 0 itemset(s) from tree conditioned on items (Input_295, Input_337)
# 14 itemset(s) from tree conditioned on items (Input_45)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_497)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_310)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_22)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_224)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_27)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_334)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_180)
# 0 itemset(s) from tree conditioned on items (Input_45, Input_328)
# 4 itemset(s) from tree conditioned on items (Input_161)
# 0 itemset(s) from tree conditioned on items (Input_161, Input_310)
# 0 itemset(s) from tree conditioned on items (Input_161, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_161, Input_276)
# 0 itemset(s) from tree conditioned on items (Input_161, Input_348)
# 12 itemset(s) from tree conditioned on items (Input_199)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_462)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_30)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_454)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_337)
# 0 itemset(s) from tree conditioned on items (Input_199, Input_118)
# 13 itemset(s) from tree conditioned on items (Input_325)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_342)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_310)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_137)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_250)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_24)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_426)
# 0 itemset(s) from tree conditioned on items (Input_325, Input_269)
# 7 itemset(s) from tree conditioned on items (Input_251)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_335)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_336)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_295)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_348)
# 0 itemset(s) from tree conditioned on items (Input_251, Input_272)
# 4 itemset(s) from tree conditioned on items (Input_450)
# 0 itemset(s) from tree conditioned on items (Input_450, Input_67)
# 0 itemset(s) from tree conditioned on items (Input_450, Input_365)
# 0 itemset(s) from tree conditioned on items (Input_450, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_450, Input_84)
# 8 itemset(s) from tree conditioned on items (Input_240)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_336)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_84)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_269)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_486)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_367)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_234)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_328)
# 0 itemset(s) from tree conditioned on items (Input_240, Input_478)
# 7 itemset(s) from tree conditioned on items (Input_353)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_65)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_71)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_478)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_327)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_438)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_294)
# 0 itemset(s) from tree conditioned on items (Input_353, Input_482)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Case_Adj_Pval_bonf'] = np.round(multipletests(sel_case_cont_freqitems_df['Case_pvalue_more'].values, method='bonferroni')[1], 3)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Case_Adj_Pval_BH'] = np.round(multipletests(sel_case_cont_freqitems_df['Case_pvalue_more'].values, method='fdr_bh')[1], 3)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/compare_enrichment.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel_case_cont_freqitems_df['Num_tests'] = number_of_tests
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df["Cont_Obs_Count_Combo"] = cont_combos_w_zero_freq_df.uniq_items.apply(get_counts, args=(apriori_input_controls_df, ))
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df["Cont_Obs_Prob_Combo"] = cont_combos_w_zero_freq_df['Cont_Obs_Count_Combo'] / number_of_controls
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_combos_w_zero_freq_df['Cont_pvalue_more'] = cont_combos_w_zero_freq_df.apply(lambda row: binomtest(int(row['Cont_Obs_Count_Combo']), number_of_controls, row['Cont_Exp_Prob_Combo'], alternative='greater').pvalue, axis=1)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Case_Exp_Count_Combo'] = round((all_sig_case_cont_freqitems_df['Case_Exp_Prob_Combo'] * number_of_cases), 2)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Cont_Exp_Count_Combo'] = round((all_sig_case_cont_freqitems_df['Cont_Exp_Prob_Combo'] * number_of_controls), 2)
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Effect_Size'] = all_sig_case_cont_freqitems_df.apply(
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Power_One_Pct'] = round(all_sig_case_cont_freqitems_df.apply(
# /data6/deepro/miniconda3/envs/pyrarecombtest/lib/python3.11/site-packages/pyrarecomb/utils/helpers.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sig_case_cont_freqitems_df['Power_Five_Pct'] = round(all_sig_case_cont_freqitems_df.apply(

# %%
out_df
# Out:
#         Item_1     Item_2           uniq_items  Case_Obs_Count_Combo  \
# 5    Input_328  Input_372  Input_328|Input_372                   6.0
# 13    Input_29  Input_372   Input_29|Input_372                   5.0
# 54    Input_39  Input_300   Input_300|Input_39                   5.0
# 59   Input_153   Input_65   Input_153|Input_65                   8.0
# 73   Input_251  Input_342  Input_251|Input_342                   5.0
# 113  Input_250  Input_450  Input_250|Input_450                   5.0
# 127  Input_462   Input_33   Input_33|Input_462                   5.0
# 152   Input_30  Input_348   Input_30|Input_348                  10.0
# 154  Input_342   Input_30   Input_30|Input_342                   8.0
# 157   Input_30  Input_372   Input_30|Input_372                   5.0
# 178  Input_447  Input_250  Input_250|Input_447                   6.0
# 194  Input_234  Input_161  Input_161|Input_234                   6.0
# 199  Input_224  Input_256  Input_224|Input_256                   6.0
# 268  Input_269   Input_27   Input_269|Input_27                   7.0
# 270   Input_60  Input_500   Input_500|Input_60                   5.0
# 283  Input_294   Input_24   Input_24|Input_294                   5.0
# 284  Input_294  Input_342  Input_294|Input_342                   5.0
# 285    Input_9  Input_234    Input_234|Input_9                   6.0
# 288  Input_349  Input_421  Input_349|Input_421                   5.0
# 291  Input_119  Input_478  Input_119|Input_478                   5.0
# 292   Input_55  Input_353   Input_353|Input_55                   5.0
#
#      Case_Obs_Count_I1  Case_Obs_Count_I2  Case_Exp_Prob_Combo  \
# 5                   72                 58             0.000675
# 13                  23                 58             0.000216
# 54                  35                 54             0.000305
# 59                  27                 80             0.000349
# 73                  25                121             0.000489
# 113                142                 25             0.000573
# 127                 73                 36             0.000425
# 152                 49                117             0.000926
# 154                121                 49             0.000958
# 157                 49                 58             0.000459
# 178                 32                142             0.000734
# 194                165                 19             0.000506
# 199                 77                 52             0.000647
# 268                106                 34             0.000582
# 270                 34                 84             0.000461
# 283                 19                 57             0.000175
# 284                 19                121             0.000371
# 285                 17                165             0.000453
# 288                 24                 55             0.000213
# 291                 11                152             0.000270
# 292                 19                 14             0.000043
#
#      Case_Obs_Prob_Combo  Case_pvalue_more  Cont_Obs_Count_Combo  ...  \
# 5               0.002412      7.520220e-03                   0.0  ...
# 13              0.002010      2.361539e-04                   0.0  ...
# 54              0.002010      1.122807e-03                   0.0  ...
# 59              0.003215      3.681012e-06                   1.0  ...
# 73              0.002010      8.147192e-03                   0.0  ...
# 113             0.002010      1.530908e-02                   0.0  ...
# 127             0.002010      4.586176e-03                   0.0  ...
# 152             0.004019      1.445197e-04                   2.0  ...
# 154             0.003215      3.183206e-03                   0.0  ...
# 157             0.002010      6.327852e-03                   0.0  ...
# 178             0.002412      1.104879e-02                   0.0  ...
# 194             0.002412      1.905305e-03                   0.0  ...
# 199             0.002412      6.186712e-03                   0.0  ...
# 268             0.002814      7.539108e-04                   0.0  ...
# 270             0.002010      6.455869e-03                   0.0  ...
# 283             0.002010      9.048240e-05                   0.0  ...
# 284             0.002010      2.615619e-03                   0.0  ...
# 285             0.002412      1.092090e-03                   0.0  ...
# 288             0.002010      2.250565e-04                   0.0  ...
# 291             0.002010      6.535229e-04                   0.0  ...
# 292             0.002010      1.060869e-07                   0.0  ...
#
#      Case_Adj_Pval_bonf  Case_Adj_Pval_BH  Num_tests  Case_Exp_Count_Combo  \
# 5                 1.000             0.026        246                  1.68
# 13                0.058             0.003        246                  0.54
# 54                0.276             0.008        246                  0.76
# 59                0.001             0.000        246                  0.87
# 73                1.000             0.028        246                  1.22
# 113               1.000             0.043        246                  1.43
# 127               1.000             0.021        246                  1.06
# 152               0.036             0.003        246                  2.30
# 154               0.783             0.017        246                  2.38
# 157               1.000             0.024        246                  1.14
# 178               1.000             0.032        246                  1.83
# 194               0.469             0.012        246                  1.26
# 199               1.000             0.024        246                  1.61
# 268               0.185             0.006        246                  1.45
# 270               1.000             0.024        246                  1.15
# 283               0.022             0.002        246                  0.44
# 284               0.643             0.015        246                  0.92
# 285               0.269             0.008        246                  1.13
# 288               0.055             0.003        246                  0.53
# 291               0.161             0.006        246                  0.67
# 292               0.000             0.000        246                  0.11
#
#      Cont_Exp_Count_Combo  Effect_Size  Power_One_Pct  Power_Five_Pct  \
# 5                    1.43     0.098255          0.815           0.935
# 13                   0.42     0.089688          0.724           0.887
# 54                   0.52     0.089688          0.724           0.887
# 59                   0.90     0.073563          0.510           0.739
# 73                   0.86     0.089688          0.724           0.887
# 113                  0.63     0.089688          0.724           0.887
# 127                  1.05     0.089688          0.724           0.887
# 152                  1.89     0.070440          0.466           0.702
# 154                  1.42     0.113470          0.924           0.980
# 157                  0.80     0.089688          0.724           0.887
# 178                  1.16     0.098255          0.815           0.935
# 194                  1.57     0.098255          0.815           0.935
# 199                  1.47     0.098255          0.815           0.935
# 268                  2.25     0.106135          0.880           0.963
# 270                  0.83     0.089688          0.724           0.887
# 283                  0.25     0.089688          0.724           0.887
# 284                  0.49     0.089688          0.724           0.887
# 285                  1.50     0.098255          0.815           0.935
# 288                  0.38     0.089688          0.724           0.887
# 291                  0.37     0.089688          0.724           0.887
# 292                  0.07     0.089688          0.724           0.887
#
#                                           Case_Samples  \
# 5    Sample_1176|Sample_1867|Sample_2176|Sample_263...
# 13   Sample_7|Sample_370|Sample_399|Sample_2961|Sam...
# 54   Sample_568|Sample_1392|Sample_3244|Sample_3809...
# 59   Sample_9|Sample_170|Sample_906|Sample_1010|Sam...
# 73   Sample_982|Sample_2352|Sample_2447|Sample_2904...
# 113  Sample_865|Sample_1494|Sample_2566|Sample_4035...
# 127  Sample_2118|Sample_2838|Sample_3885|Sample_403...
# 152  Sample_247|Sample_868|Sample_1224|Sample_1525|...
# 154  Sample_389|Sample_1525|Sample_2734|Sample_3040...
# 157  Sample_1603|Sample_2118|Sample_2734|Sample_449...
# 178  Sample_87|Sample_302|Sample_1367|Sample_2998|S...
# 194  Sample_970|Sample_1175|Sample_1255|Sample_1306...
# 199  Sample_1725|Sample_1943|Sample_3096|Sample_393...
# 268  Sample_702|Sample_1921|Sample_1963|Sample_2269...
# 270  Sample_270|Sample_921|Sample_1965|Sample_2411|...
# 283  Sample_509|Sample_868|Sample_2186|Sample_2360|...
# 284  Sample_1465|Sample_2186|Sample_2360|Sample_238...
# 285  Sample_2449|Sample_2458|Sample_2862|Sample_382...
# 288  Sample_709|Sample_888|Sample_1805|Sample_1866|...
# 291  Sample_1010|Sample_1405|Sample_3799|Sample_473...
# 292  Sample_1425|Sample_2118|Sample_2284|Sample_403...
#
#              Control_Samples
# 5
# 13
# 54
# 59                Sample_368
# 73
# 113
# 127
# 152  Sample_1125|Sample_3073
# 154
# 157
# 178
# 194
# 199
# 268
# 270
# 283
# 284
# 285
# 288
# 291
# 292
#
# [21 rows x 25 columns]
